# %%
import numpy as np
from matplotlib import pyplot as plt
from astropy import units as u
from astropy import constants as c
from scipy.integrate import quad
from scipy.interpolate import CubicSpline
from scipy.optimize import curve_fit

# %%
# import ROOT as r
# import warnings
# warnings.filterwarnings('ignore')

# %%
# r.gSystem.Load('$EVNDISPSYS/lib/libVAnaSum.so')

# %%
# filename = '/raid/reedbuck/lrizk/veritas/simulations/evndisp/muons/820800.root'
# sim_820800 = r.TFile(filename)
# params = sim_820800.Get('Tel_2/tpars')

# %%
# num_events = 0
# for event in params:
#     if event.muonValid and event.muonRadius:
#         num_events += 1

# %%
# sim_muon_params = np.zeros((3, num_events))
# i = 0

# for event in params:
#     if event.muonValid and event.muonRadius:
#         sim_muon_params[0][i] = event.muonRadius
#         sim_muon_params[1][i] = event.muonRSigma
#         sim_muon_params[2][i] = event.muonIPCorrectedSize
#         i += 1

# %%
# output = 'sim_data/muons_820800.csv'
# np.savetxt(output, sim_muon_params.T, delimiter=',')

# %%
sims = '../sim_data/muons_820800.csv'
muon_radii, muon_radii_err, muon_sizes = np.loadtxt(sims, delimiter=',', unpack=True)

# %%
fig, ax = plt.subplots(figsize=(10, 4))

plt.scatter(muon_radii, muon_sizes, c='orangered', marker='o', s=10, alpha=0.1)

plt.grid(alpha=0.4)
plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel('Digital counts')
plt.title('Muon ring radius vs. size')

plt.xlim(xmin=0)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 4))

plt.errorbar(x=muon_radii[:1000], xerr=muon_radii_err[:1000], y=muon_sizes[:1000],
             c='orangered', marker='o', ms=3, ls='', alpha=0.2)

plt.grid(alpha=0.4)
plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel('Digital counts')
plt.title('Muon ring radius vs. size')

plt.xlim(xmin=0)
plt.ylim(0, 1e4)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 4))

hist_data = plt.hist(muon_radii_err, bins=100, edgecolor='royalblue', color='dodgerblue')

plt.grid(alpha=0.8)
plt.xlabel('Muon ring radius error  [°]')
plt.ylabel('Abundance')
plt.title('Distribution of errors in muon ring radius')

plt.show()

# %%
# err_cutoff = hist_data[1][9]
err_cutoff = 0.11

fig, ax = plt.subplots(figsize=(10, 4))

plt.hist(muon_radii_err, bins=100, edgecolor='royalblue', color='dodgerblue')
plt.axvline(x=err_cutoff, c='black', ls='--', label='Cutoff')

plt.grid(alpha=0.8)
plt.xlabel('Muon ring radius error  [°]')
plt.ylabel('Abundance')
plt.title('Distribution of errors in muon ring radius')

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 4))

plt.errorbar(x=muon_radii[muon_radii_err < err_cutoff], 
             xerr=muon_radii_err[muon_radii_err < err_cutoff],
             y=muon_sizes[muon_radii_err < err_cutoff],
             c='orangered', marker='o', ms=3, ls='', alpha=0.1)

plt.grid(alpha=0.4)
plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel('Digital counts')
plt.title('Muon ring radius vs. size')

plt.xlim(xmin=0)

plt.show()

# %%
directory = '../output/'

muon_E_span = np.load(directory + 'muon_E.npy')
angles_deg = np.load(directory + 'ring_radii.npy')
true_ring_intensities = np.load(directory + 'muon_ring_sizes.npy')
true_ring_intensities_MM = np.load(directory + 'MM_ring_sizes.npy')

# %%
def linear(y, a, b):

    a_prime = 1/a
    b_prime = -b/a
    
    return a_prime * y + b_prime

# %%
def linear_0(y, a):

    a_prime = 1/a
    
    return a_prime * y

# %%
# theory_fit = curve_fit(
#     linear, 
#     ydata=angles_deg[angles_deg * true_ring_intensities > 0], 
#     xdata=true_ring_intensities[angles_deg * true_ring_intensities > 0], 
#     p0=[5000, 0])

theory_fit = curve_fit(
    linear, 
    ydata=angles_deg[angles_deg > 0.2], 
    xdata=true_ring_intensities[angles_deg > 0.2], 
    p0=[5000, 0])

theory_slope, theory_intercept = theory_fit[0]

# %%
GAIN = 2  # (guess)

fig, ax = plt.subplots(figsize=(8, 4))

plt.errorbar(x=muon_radii[muon_radii_err < err_cutoff], 
             xerr=muon_radii_err[muon_radii_err < err_cutoff],
             y=muon_sizes[muon_radii_err < err_cutoff],
             c='firebrick', marker='o', ms=3, ls='', alpha=0.4,
             label=r'Sim data with $\sigma_\theta$ < {}'.format(round(err_cutoff, 2)))

plt.plot(angles_deg, true_ring_intensities * GAIN, c='dodgerblue', lw=2,
         label='Theoretical size vs. radius curve (scaled)')

plt.grid(alpha=0.4)
plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel('Digital counts')
plt.title('Muon ring radius vs. size')

plt.xlim(xmin=0)
# plt.ylim(0, 1e4)

plt.legend()
plt.show()

# %%
fit = curve_fit(
    linear,
    xdata=muon_sizes[muon_radii_err < err_cutoff], 
    ydata=muon_radii[muon_radii_err < err_cutoff],
    sigma=muon_radii_err[muon_radii_err < err_cutoff], 
    absolute_sigma=True, 
    p0=[5000, 0],
)

# %%
slope, intercept = fit[0]
print('Sim data slope:', slope)
print('Theory slope:', theory_slope)
# Out:
# Sim data slope: 7086.966617316281
# Theory slope: 1757.7608151786783

# %%
angles_range = np.linspace(
    np.min(muon_radii[muon_radii_err < err_cutoff]) - 0.05,
    np.max(muon_radii[muon_radii_err < err_cutoff]) + 0.05,
    1000
) 

fig, ax = plt.subplots(figsize=(8, 4))

plt.errorbar(x=muon_radii[muon_radii_err < err_cutoff], 
             xerr=muon_radii_err[muon_radii_err < err_cutoff],
             y=muon_sizes[muon_radii_err < err_cutoff],
             c='firebrick', marker='o', ms=3, ls='', alpha=0.2,
             label=r'Sim data with $\sigma_\theta$ < {}'.format(round(err_cutoff, 2)))

plt.plot(angles_range, slope * angles_range + intercept, c='blueviolet', lw=2,
         label=r'Linear fit: $N \, = \, {} \, \theta \, + \, {}$'.format(
             round(slope, 2), 
             round(intercept, 2),
         ))


plt.grid(alpha=0.4)
plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel('Digital counts')
plt.title('Muon ring radius vs. size')

plt.xlim(xmin=0)
# plt.ylim(0, 1e4)

plt.legend()
plt.show()

# %%
# Chi2 test

model_guesses = linear(muon_sizes[muon_radii_err < err_cutoff], slope, intercept)

chi2 = np.sum((model_guesses - muon_radii[muon_radii_err < err_cutoff])**2 
              / (muon_radii_err[muon_radii_err < err_cutoff])**2)
dof = len(model_guesses) - 2
red_chi2 = chi2/dof
print(red_chi2)
# Out:
# 3.6008689664311597

# %%
fit_0 = curve_fit(
    linear_0,
    xdata=muon_sizes[muon_radii_err < err_cutoff], 
    ydata=muon_radii[muon_radii_err < err_cutoff],
    sigma=muon_radii_err[muon_radii_err < err_cutoff], 
    absolute_sigma=True, 
    p0=[5000],
)

# %%
slope_0 = fit_0[0][0]
print('Sim data slope:', slope_0)
print('Theory slope:', theory_slope)
# Out:
# Sim data slope: 3930.7438377512885
# Theory slope: 1757.7608151786783

# %%
GAIN = slope_0 / theory_slope

angles_range = np.linspace(
    np.min(muon_radii[muon_radii_err < err_cutoff]) - 0.05,
    np.max(muon_radii[muon_radii_err < err_cutoff]) + 0.05,
    1000
) 

fig, ax = plt.subplots(figsize=(8, 4))

plt.errorbar(x=muon_radii[muon_radii_err < err_cutoff], 
             xerr=muon_radii_err[muon_radii_err < err_cutoff],
             y=muon_sizes[muon_radii_err < err_cutoff],
             c='firebrick', marker='o', ms=3, ls='', alpha=0.08,
             label=r'Sim data with $\sigma_\theta$ < {}'.format(round(err_cutoff, 2)))

plt.plot(angles_range, slope_0 * angles_range, c='blueviolet', lw=2.5,
         label=r'Linear fit: $N \, = \, {} \, \theta$'.format(
             round(slope_0, 2), 
         ))

plt.plot(angles_deg, true_ring_intensities * GAIN, c='dodgerblue', lw=2, ls='--',
         label='Theoretical size vs. radius curve (scaled)')

plt.grid(alpha=0.4)
plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel('Digital counts')
plt.title('Muon ring radius vs. size')

plt.xlim(xmin=0)
# plt.ylim(0, 1e4)

plt.legend()
plt.show()

# %%
# Chi2 test

model_guesses_0 = linear_0(muon_sizes[muon_radii_err < err_cutoff], slope)

chi2 = np.sum((model_guesses_0 - muon_radii[muon_radii_err < err_cutoff])**2 
              / (muon_radii_err[muon_radii_err < err_cutoff])**2)
dof = len(model_guesses_0) - 1
red_chi2 = chi2/dof
print(red_chi2)
# Out:
# 73.98994376164087

# %%
histobins = np.arange(0, 1.5, 0.1)

fig, ax = plt.subplots(figsize=(8, 4))

plt.hist(muon_radii[muon_radii_err < err_cutoff], bins=histobins, density=True,
         edgecolor='firebrick', lw=2, color='orangered')

plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel('Relative abundance')
plt.title('Distribution of muon ring radii')

plt.xlim(histobins[0], histobins[-1])

plt.show()

# %%
muon_mass = (105.65837 * u.MeV/c.c**2).to(u.kg).value  # kg
veritas_alt = 1268  # m
optimal_wvl = 380*1e-9

def n_air(lam, alt=veritas_alt):

    # Empirically determined constants
    A = 2.73e-4 
    B = 1.23e-18  # m^2
    C = 3.56e-32  # m^4
    
    # Scale height of the atmosphere
    h_0 = 8.4e3  # m

    epsilon_0 = A + B/lam**2 + C/lam**4
    epsilon = epsilon_0 * np.exp(-alt / h_0)
    
    return 1 + epsilon

def get_beta(E, m=c.m_e.value):

    return np.sqrt(1 - m**2 * c.c.value**4 / E**2)

def get_cherenkov_angle(beta, n):

    return np.arccos(1 / (beta * n))

def dNdtheta(theta, N_tot, E_min, E_max, index, n, m):

    a = N_tot * (index+1) / (E_max**(index+1) - E_min**(index+1))

    A = a * (m * c.c.value**2) ** (index+1)
    B = (1 - n**-2 * np.cos(theta)**-2) ** (-0.5*index - 1.5)
    C = np.tan(theta) * n**-2 * np.cos(theta)**-2

    return A * B * C

N_tot = 1e5
E_min = 5 * u.GeV.to(u.J)  # J
E_max = 100 * u.GeV.to(u.J)  # J
index = -1.5

reference_n = n_air(optimal_wvl)
asymptotic_theta = get_cherenkov_angle(beta=1, n=reference_n)
sample_thetas = np.linspace(
    get_cherenkov_angle(beta=get_beta(E_min, m=muon_mass), n=reference_n),
    get_cherenkov_angle(beta=get_beta(E_max, m=muon_mass), n=reference_n),
    10000
)

# %%
fig, ax = plt.subplots(figsize=(8, 4))

plt.hist(muon_radii[muon_radii_err < err_cutoff], bins=100, density=True,
         color='orangered', lw=2)

plt.plot(sample_thetas / np.pi * 180, 
         dNdtheta(sample_thetas, N_tot, E_min, E_max, index, n=reference_n, m=muon_mass) 
         * np.pi / 180 / N_tot,
         c='royalblue', lw=1.5,
         label='Expected distribution of Cherenkov angles at {} nm'.format(int(optimal_wvl * 1e9)))

plt.axvline(asymptotic_theta / np.pi * 180, 
            label='Asymptote at {} nm: '.format(int(optimal_wvl * 1e9))
            + r'$\theta_{C, \mathrm{max}}$ = ' 
            + str(round(asymptotic_theta / np.pi * 180, 3)) + '°',
            c='black', lw=1.5, ls='--')

plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel(r'$\frac{dN}{d\theta_C}$  [1/°]')
plt.title('Distribution of muon ring radii')

plt.xlim(histobins[0], histobins[-1])
plt.ylim(0, 11)

plt.legend()
plt.show()

# %%
# Other method for fitting:

good_muon_radii = muon_radii[muon_radii_err < err_cutoff]
good_muon_radii_err = muon_radii_err[muon_radii_err < err_cutoff]
good_muon_sizes = muon_sizes[muon_radii_err < err_cutoff]

values, bin_edges = np.histogram(good_muon_radii, bins=100, density=True)
ref = 20 * values[0]

select_muon_radii = []
select_muon_radii_err = []
select_muon_sizes = []

for i in range(len(bin_edges) - 1):
    bin_muon_radii = good_muon_radii[(bin_edges[i] <= good_muon_radii) & (good_muon_radii < bin_edges[i+1])]
    bin_muon_radii_err = good_muon_radii_err[(bin_edges[i] <= good_muon_radii) & (good_muon_radii < bin_edges[i+1])]
    bin_muon_sizes = good_muon_sizes[(bin_edges[i] <= good_muon_radii) & (good_muon_radii < bin_edges[i+1])]
    scale = int(values[i] / ref)
    if scale == 0:
        scale = 1
    fewer_muon_radii = bin_muon_radii[::scale]
    fewer_muon_radii_err = bin_muon_radii_err[::scale]
    fewer_muon_sizes = bin_muon_sizes[::scale]
    select_muon_radii += fewer_muon_radii.tolist()
    select_muon_radii_err += fewer_muon_radii_err.tolist()
    select_muon_sizes += fewer_muon_sizes.tolist()

select_muon_radii = np.array(select_muon_radii)
select_muon_radii_err = np.array(select_muon_radii_err)
select_muon_sizes = np.array(select_muon_sizes)

# %%
fit = curve_fit(
    linear,
    xdata=select_muon_sizes, 
    ydata=select_muon_radii,
    sigma=select_muon_radii_err, 
    absolute_sigma=True, 
    p0=[5000, 0],
)

# %%
slope, intercept = fit[0]
print('Sim data slope:', slope)
print('Theory slope:', theory_slope)
# Out:
# Sim data slope: 5288.306698392726
# Theory slope: 1757.7608151786783

# %%
angles_range = np.linspace(
    np.min(muon_radii[muon_radii_err < err_cutoff]) - 0.05,
    np.max(muon_radii[muon_radii_err < err_cutoff]) + 0.05,
    1000
) 

fig, ax = plt.subplots(figsize=(8, 4))

plt.errorbar(x=select_muon_radii, 
             xerr=select_muon_radii_err,
             y=select_muon_sizes,
             c='firebrick', marker='o', ms=3, ls='', alpha=0.2,
             label=r'Sim data with $\sigma_\theta$ < {}'.format(round(err_cutoff, 2)))

plt.plot(angles_range, slope * angles_range + intercept, c='blueviolet', lw=2,
         label=r'Linear fit: $N \, = \, {} \, \theta \, + \, {}$'.format(
             round(slope, 2), 
             round(intercept, 2),
         ))


plt.grid(alpha=0.4)
plt.xlabel('Muon ring radius (Cherenkov angle)  [°]')
plt.ylabel('Digital counts')
plt.title('Muon ring radius vs. size')

plt.xlim(xmin=0)
# plt.ylim(0, 1e4)

plt.legend()
plt.show()

# %%
# Chi2 test

model_guesses = linear(muon_sizes[muon_radii_err < err_cutoff], slope, intercept)

chi2 = np.sum((model_guesses - muon_radii[muon_radii_err < err_cutoff])**2 
              / (muon_radii_err[muon_radii_err < err_cutoff])**2)
dof = len(model_guesses) - 2
red_chi2 = chi2/dof
print(red_chi2)
# Out:
# 4.939763471244122
